# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import io
import json
#from sklearn.cluster import KMeans

# %%
# upload one file, step 1/2
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-15dafefc-bfdb-4ee7-ac0f-fadde8099f8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15dafefc-bfdb-4ee7-ac0f-fadde8099f8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 6DOF.json to 6DOF (1).json

# %%
## upload 1 file, step 2/2
raw_data = []
for file_name in uploaded.keys():
  io.StringIO(uploaded[file_name].decode("utf-8"))
  raw_data.append(json.loads(uploaded[file_name].decode("utf-8")))

# %%
print(raw_data)
# Out:
# [{'accX': [159.88013076782227, 154.6923065185547, 168.05430603027344, 150.38507461547852, 150.27021408081055, 169.1837615966797, 210.55235290527344, 227.8387222290039, 241.90902709960938, 217.65450286865234, 182.77547454833984, 155.28574752807617, 142.44061660766602, 133.55814361572266, 116.99921989440918, 111.06480693817139, 114.43402194976807, 145.8672637939453, 202.32074737548828, 238.34837341308594, 219.47311401367188, 176.17105102539062, 154.1562957763672, 145.88640594482422, 139.68398666381836, 126.13055610656738, 137.06135940551758, 84.39823913574219, 96.55421233177185, 97.18594002723694, 110.0885009765625, 130.70579719543457, 138.82254028320312, 141.67488861083984, 140.5262908935547, 161.46902465820312, 170.88751220703125, 159.17183303833008, 148.75789642333984, 151.76338958740234, 152.43340301513672, 132.4095458984375, 101.62717747688293, 95.59704923629761, 63.0726432800293, 53.59672546386719, 49.557498931884766, 61.15831756591797, 60.85202407836914, 48.3897590637207, 58.076
# ...

# %%
print(raw_data[0])
#print(raw_data[0].get('accY'))
plt.plot(raw_data[0].get('accX'))
plt.plot(raw_data[0].get('accY'))
plt.plot(raw_data[0].get('accZ'))
#plt.legend('accX', 'accY', 'accZ')
# Out:
# {'accX': [159.88013076782227, 154.6923065185547, 168.05430603027344, 150.38507461547852, 150.27021408081055, 169.1837615966797, 210.55235290527344, 227.8387222290039, 241.90902709960938, 217.65450286865234, 182.77547454833984, 155.28574752807617, 142.44061660766602, 133.55814361572266, 116.99921989440918, 111.06480693817139, 114.43402194976807, 145.8672637939453, 202.32074737548828, 238.34837341308594, 219.47311401367188, 176.17105102539062, 154.1562957763672, 145.88640594482422, 139.68398666381836, 126.13055610656738, 137.06135940551758, 84.39823913574219, 96.55421233177185, 97.18594002723694, 110.0885009765625, 130.70579719543457, 138.82254028320312, 141.67488861083984, 140.5262908935547, 161.46902465820312, 170.88751220703125, 159.17183303833008, 148.75789642333984, 151.76338958740234, 152.43340301513672, 132.4095458984375, 101.62717747688293, 95.59704923629761, 63.0726432800293, 53.59672546386719, 49.557498931884766, 61.15831756591797, 60.85202407836914, 48.3897590637207, 58.0762
# ...

# %%
raw_data[0].keys()
# Out:
# dict_keys(['accX', 'accY', 'accZ', 'magX', 'magY', 'magZ'])

# %%
plt.plot(raw_data[0].get('magX'))
plt.plot(raw_data[0].get('magY'))
plt.plot(raw_data[0].get('magZ'))
